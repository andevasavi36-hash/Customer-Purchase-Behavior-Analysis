# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {
    "Customer_ID": range(1, 21),
    "Age": [22,25,47,52,46,56,48,55,60,61,18,21,35,42,39,49,51,23,27,30],
    "Purchase_Amount": [200,150,500,650,700,1200,800,950,1100,1500,
                        100,120,450,500,550,620,710,180,220,300]
}

df = pd.DataFrame(data)

df.head()
# Out:
#    Customer_ID  Age  Purchase_Amount
# 0            1   22              200
# 1            2   25              150
# 2            3   47              500
# 3            4   52              650
# 4            5   46              700

# %%
print(df.info())

print("\nDataset Shape:", df.shape)

print("\nSummary Statistics:")
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Customer_ID      20 non-null     int64
#  1   Age              20 non-null     int64
#  2   Purchase_Amount  20 non-null     int64
# dtypes: int64(3)
# memory usage: 612.0 bytes
# None
#
# Dataset Shape: (20, 3)
#
# Summary Statistics:
#        Customer_ID        Age  Purchase_Amount
# count     20.00000  20.000000        20.000000
# mean      10.50000  40.350000       575.000000
# std        5.91608  14.135714       390.256326
# min        1.00000  18.000000       100.000000
# 25%        5.75000  26.500000       215.000000
# 50%       10.50000  44.000000       525.000000
# 75%       15.25000  51.250000       732.500000
# max       20.00000  61.000000      1500.000000

# %%
mean_purchase = df["Purchase_Amount"].mean()
median_purchase = df["Purchase_Amount"].median()
mode_purchase = df["Purchase_Amount"].mode()[0]

print("Mean Purchase:", mean_purchase)
print("Median Purchase:", median_purchase)
print("Mode Purchase:", mode_purchase)
# Out:
# Mean Purchase: 575.0
# Median Purchase: 525.0
# Mode Purchase: 500

# %%
plt.figure(figsize=(8,5))

plt.hist(df["Purchase_Amount"], bins=8)

plt.title("Purchase Amount Distribution")
plt.xlabel("Purchase Amount")
plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(6,4))

plt.boxplot(df["Purchase_Amount"])

plt.title("Purchase Amount Boxplot")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(df["Age"], df["Purchase_Amount"])

plt.title("Age vs Purchase Amount")
plt.xlabel("Age")
plt.ylabel("Purchase Amount")

plt.show()

# %%
high_spenders = df[df["Purchase_Amount"] > 800]

print("High Spending Customers:\n")
print(high_spenders)
# Out:
# High Spending Customers:
#
#    Customer_ID  Age  Purchase_Amount
# 5            6   56             1200
# 7            8   55              950
# 8            9   60             1100
# 9           10   61             1500

# %%
correlation = df["Age"].corr(df["Purchase_Amount"])

print("Correlation:", correlation)
# Out:
# Correlation: 0.9270187982622492
